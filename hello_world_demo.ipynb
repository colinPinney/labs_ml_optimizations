# %% [markdown]
# # Hello world
# ## Optimization algorithms: demo

# %% [markdown]
# <em><b>Note</b>: This is just a demo of optimization techniques - not related to any real-life problem.</em>
#
# Imagine the world of strings where the environment demands that the strings are very fit. An unfit string cannot survive.
#
# How do we define the fitness of a string? The environment demands that the string should be as similar as possible to the target string $s$=''Hello, world''. The closer the string is to ''Hello, world'', the better its chances of survival.
#
# <b> The problem:</b> given a set of random strings of length len($s$) over alphabet $\sigma=\{32 \ldots 122\}$, produce the string which best matches the environment, i.e. with a minimum fitness score.
#
# Let <em>Weighted Hamming Distance</em> between two strings $x$ and $y$ (both of length $n$) be defined as:<br>
# $WH(x,y) = \sum_{i=0}^{n} abs(x[i] - y[i])$
#
# $WH(x,y)$ estimates how far is $x$ from $y$. The lower $WH(x,y)$, the closer string $x$ approaches the target string $y$.<br>
# In the space of $\sigma^n$ of all possible strings, we are looking for a global minimum - the string $m$ such that $WH(m,s)$ is minimized. <br>
#
# If we compute $WH(x,s)$ for an arbitrary string $x$, we say that we evaluate the <em>fitness</em> of $x$ with respect to the target string $s$. This is our <em>fitness function</em>.

# %% [markdown]
# ## 1. Preparation

# %%
# flag which can be turned on/off to print the steps of each optimization
print_steps = True

# %% [markdown]
# ### 1.1. String fitness function

# %%
s = 'Hello, world'
n = len(s)

# fitness function - weighted hamming distance
string_fitness = lambda x: sum([abs(ord(x[i])- ord(s[i])) for i in range(n)])

# %% [markdown]
# ### 1.2. Generating initial random strings

# %%
import random

alphabet = range(32,123)

def get_random_string(n, sigma):    
    t = [chr(random.choice(sigma)) for i in range(n)]
    return ''.join(t)

# build initial population of many random strings of target length n
def get_rand_population(population_size, n, sigma):
    population=[]
    for i in range(0,population_size):
        individual_str = get_random_string(n, sigma)
        population.append(individual_str)
    return population

# test
print(get_random_string(len(s), alphabet))
print(get_rand_population(3, len(s), alphabet ))
# Out:
# yl$v_[7aKfE2
# ["'a$+g4TiA&md", 'q,]hHH&)Qehz', 'Sb*agA8gHm`?']

# %% [markdown]
# ## 2. Random optimize
#
# The simplest possible idea is to try a vaste amount of random solutions and select the one with the best fitness score. Let's see how close we can get to the target $s$=''Hello, world'' with this approach.
#
# After all, isn't evolution just a lottery? ''Physics makes rules, evolution rolls the dice'' ( Charles Cockell. "The Equations of Life").

# %%
def random_optimize(population, fitness_function):
    best_score = None
    best_solution = None
    for i in range(len(population)):
        # Calculate fitness 
        score = fitness_function(population[i])

        # Compare it to the best one so far
        if best_score == None or score < best_score:
            best_score = score
            best_solution = population[i]
            if print_steps:
                print(best_solution, " -> score:", best_score)
            
    return (best_score, best_solution, len(population))


# Now the test
string_population = get_rand_population(204800, len(s), alphabet)

best_score, best_sol, iterations = random_optimize (string_population, string_fitness)
# Out:
# FV:Z1VI#Q@0C  -> score: 487
# @o)?INe%bgy:  -> score: 432
# <k]XCY*\G[^o  -> score: 267
# 5^e8MD)piPUc  -> score: 223
# 0f]it*O9huKs  -> score: 217
# 6hfm?% `VAwb  -> score: 193
# 0pHkg'EpcpvM  -> score: 176
# GOf8p!!Voe\k  -> score: 163
# 6TeKn"6yveg[  -> score: 144
# !ccqhF+ipk^^  -> score: 141
# FX_On&#fp]mj  -> score: 113

# %%
print()
print("*************Rand optimize**************")
print("trials:{}, best solution:'{}', best score:{}".format(iterations,best_sol,best_score))
# Out:
# *************Rand optimize**************
# trials:204800, best solution:'FX_On&#fp]mj', best score:113

# %% [markdown]
# Randomly trying different solutions is very inefficient because the probability of getting anything close to perfect Hello, world is $(\frac{1}{90})^{12}$. No matter how many random guesses you try – the fitness of the resulting string is very low (the distance from the target remains high).

# %% [markdown]
# ## 3. Hill climbing
#
# We did not advance far with the random optimization. This happens because each time we come up with some solution and evaluate its fitness - we discard it and try another one - not related to the previous.
#
# The idea behing the <em>hill climbing</em> optimization is to start at a random point in space (choose one random string), and try to move from this point into a direction of better fitness. We will generate a set of neighbors for a randomly selected string, and see if any of these neighbors improve the overall fitness score of the string.
#
# We continue moving into the direction of this better solution, until there is no more improvement.
#
# <img src="images/hillclimbing.jpg" style="height:200px;">
#
#
# The algorithm may produce an optimal solution, but it may also get stuck at the local minimum.
# <img src="images/localmin.jpg" style="height:200px;">

# %%
def hillclimb_optimize(start_point, fitness_function):
    sol = start_point
    score = fitness_function(sol)
    iterations = 0
    
    # Main loop
    while 1:
        iterations += 1
        
        current_best_score = score
        # Create  neighboring solutions
        neighbors=[]

        for j in range(len(s)):
            # Change character at position j one up or one down
            if ord(sol[j])>32:
                neighbors.append(sol[0:j]+chr(ord(sol[j])-1)+sol[j+1:])
            if ord(sol[j])<122:
                neighbors.append(sol[0:j]+chr(ord(sol[j])+1)+sol[j+1:])
        
        for n_str in neighbors:
            n_score = fitness_function(n_str)
            if n_score < score:
                score = n_score
                sol = n_str
                if print_steps:
                    print(sol, " -> score:", score)      
        
        # If there's no improvement, then we've reached the bottom of the hill
        if score == current_best_score:
            break        
        
        if score == 0:
            break        
        
    return (score, sol, iterations)

# Now the test

rand_str = get_random_string(len(s), alphabet)
best_score, best_sol, iterations = hillclimb_optimize(rand_str, string_fitness)
# Out:
# tKtdA,Q^1ZI+  -> score: 384
# sKtdA,Q^1ZI+  -> score: 383
# rKtdA,Q^1ZI+  -> score: 382
# qKtdA,Q^1ZI+  -> score: 381
# pKtdA,Q^1ZI+  -> score: 380
# oKtdA,Q^1ZI+  -> score: 379
# nKtdA,Q^1ZI+  -> score: 378
# mKtdA,Q^1ZI+  -> score: 377
# lKtdA,Q^1ZI+  -> score: 376
# kKtdA,Q^1ZI+  -> score: 375
# jKtdA,Q^1ZI+  -> score: 374
# iKtdA,Q^1ZI+  -> score: 373
# hKtdA,Q^1ZI+  -> score: 372
# gKtdA,Q^1ZI+  -> score: 371
# fKtdA,Q^1ZI+  -> score: 370
# eKtdA,Q^1ZI+  -> score: 369
# dKtdA,Q^1ZI+  -> score: 368
# cKtdA,Q^1ZI+  -> score: 367
# bKtdA,Q^1ZI+  -> score: 366
# aKtdA,Q^1ZI+  -> score: 365
# `KtdA,Q^1ZI+  -> score: 364
# HellC,Q^1ZI+  -> score: 296
# HellD,Q^1ZI+  -> score: 295
# HellE,Q^1ZI+  -> score: 294
# HellF,Q^1ZI+  -> score: 293
# HellG,Q^1ZI+  -> score: 292
# HellH,Q^1ZI+  -> score: 291
# HellI,Q^1ZI+  -> score: 290
# HellJ,Q^1ZI+  -> score: 289
# HellK,Q^1ZI+  -> score: 288
# HellL,Q^1ZI+  -> score: 287
# HellM,Q^1ZI+  -> score: 286
# HellN,Q^1ZI+  -> score: 285
# HellO,Q^1ZI+  -> score: 284
# HellP,Q^1ZI+  -> score: 283
# HellQ,Q^1ZI+  -> score: 282
# HellR,Q^1ZI+  -> score: 281
# HellS,Q^1ZI+  -> score: 280
# HellT,Q^1ZI+  -> score: 279
# HellU,Q^1ZI+  -> score: 278
# HellV,Q^1ZI+  -> score: 277
# HellW,Q^1ZI+  -> score: 276
# HellX,Q^1ZI+  -> score: 275
# HellY,Q^1ZI+  -> score: 274
# HellZ,Q^1ZI+  -> score: 273
# Hell[,Q^1ZI+  -> score: 272
# Hell\,Q^1ZI+  -> score: 271
# Hell],Q^1ZI+  -> score: 270
# Hell^,Q^1ZI+  -> score: 269
# Hell_,Q^1ZI+  -> score: 268
# Hell`,Q^1ZI+  -> score: 267
# Hella,Q^1ZI+  -> score: 266
# Hellb,Q^1ZI+  -> score: 265
# Hellc,Q^1ZI+  -> score: 264
# Helld,Q^1ZI+  -> score: 263
# Helle,Q^1ZI+  -> score: 262
# Hellf,Q^1ZI+  -> score: 261
# Hellg,Q^1ZI+  -> score: 260
# Hellh,Q^1ZI+  -> score: 259
# Helli,Q^1ZI+  -> score: 258
# Hellj,Q^1ZI+  -> score: 257
# Hellk,Q^1ZI+  -> score: 256
# Helll,Q^1ZI+  -> score: 255
# Hellm,Q^1ZI+  -> score: 254
# Helln,Q^1ZI+  -> score: 253
# Hello,Q^1ZI+  -> score: 252
# Hello,P^1ZI+  -> score: 251
# Hello,O^1ZI+  -> score: 250
# Hello,N^1ZI+  -> score: 249
# Hello,M^1ZI+  -> score: 248
# Hello,L^1ZI+  -> score: 247
# Hello,K^1ZI+  -> score: 246
# Hello,J^1ZI+  -> score: 245
# Hello,I^1ZI+  -> score: 244
# Hello,H^1ZI+  -> score: 243
# Hello,G^1ZI+  -> score: 242
# Hello,F^1ZI+  -> score: 241
# Hello,E^1ZI+  -> score: 240
# Hello,D^1ZI+  -> score: 239
# Hello,C^1ZI+  -> score: 238
# Hello,B^1ZI+  -> score: 237
# Hello,A^1ZI+  -> score: 236
# Hello,@^1ZI+  -> score: 235
# Hello,?^1ZI+  -> score: 234
# Hello,>^1ZI+  -> score: 233
# Hello,=^1ZI+  -> score: 232
# Hello,<^1ZI+  -> score: 231
# Hello,;^1ZI+  -> score: 230
# Hello,:^1ZI+  -> score: 229
# Hello,9^1ZI+  -> score: 228
# Hello,8^1ZI+  -> score: 227
# Hello,7^1ZI+  -> score: 226
# Hello,6^1ZI+  -> score: 225
# Hello,5^1ZI+  -> score: 224
# Hello,4^1ZI+  -> score: 223
# Hello,3^1ZI+  -> score: 222
# Hello,2^1ZI+  -> score: 221
# Hello,1^1ZI+  -> score: 220
# Hello,0^1ZI+  -> score: 219
# Hello,/^1ZI+  -> score: 218
# Hello,.^1ZI+  -> score: 217
# Hello,-^1ZI+  -> score: 216
# Hello,,^1ZI+  -> score: 215
# Hello,+^1ZI+  -> score: 214
# Hello,*^1ZI+  -> score: 213
# Hello,)^1ZI+  -> score: 212
# Hello,(^1ZI+  -> score: 211
# Hello,'^1ZI+  -> score: 210
# Hello,&^1ZI+  -> score: 209
# Hello,%^1ZI+  -> score: 208
# Hello,$^1ZI+  -> score: 207
# Hello,#^1ZI+  -> score: 206
# Hello,"^1ZI+  -> score: 205
# Hello,!^1ZI+  -> score: 204
# Hello, ^1ZI+  -> score: 203
# Hello, _1ZI+  -> score: 202
# Hello, `1ZI+  -> score: 201
# Hello, a1ZI+  -> score: 200
# Hello, b1ZI+  -> score: 199
# Hello, c1ZI+  -> score: 198
# Hello, d1ZI+  -> score: 197
# Hello, e1ZI+  -> score: 196
# Hello, f1ZI+  -> score: 195
# Hello, g1ZI+  -> score: 194
# Hello, h1ZI+  -> score: 193
# Hello, i1ZI+  -> score: 192
# Hello, j1ZI+  -> score: 191
# Hello, k1ZI+  -> score: 190
# Hello, l1ZI+  -> score: 189
# Hello, m1ZI+  -> score: 188
# Hello, n1ZI+  -> score: 187
# Hello, o1ZI+  -> score: 186
# Hello, p1ZI+  -> score: 185
# Hello, q1ZI+  -> score: 184
# Hello, r1ZI+  -> score: 183
# Hello, s1ZI+  -> score: 182
# Hello, t1ZI+  -> score: 181
# Hello, u1ZI+  -> score: 180
# Hello, v1ZI+  -> score: 179
# Hello, w1ZI+  -> score: 178
# Hello, w2ZI+  -> score: 177
# Hello, w3ZI+  -> score: 176
# Hello, w4ZI+  -> score: 175
# Hello, w5ZI+  -> score: 174
# Hello, w6ZI+  -> score: 173
# Hello, w7ZI+  -> score: 172
# Hello, w8ZI+  -> score: 171
# Hello, w9ZI+  -> score: 170
# Hello, w:ZI+  -> score: 169
# Hello, w;ZI+  -> score: 168
# Hello, w<ZI+  -> score: 167
# Hello, w=ZI+  -> score: 166
# Hello, w>ZI+  -> score: 165
# Hello, w?ZI+  -> score: 164
# Hello, w@ZI+  -> score: 163
# Hello, wAZI+  -> score: 162
# Hello, wBZI+  -> score: 161
# Hello, wCZI+  -> score: 160
# Hello, wDZI+  -> score: 159
# Hello, wEZI+  -> score: 158
# Hello, wFZI+  -> score: 157
# Hello, wGZI+  -> score: 156
# Hello, wHZI+  -> score: 155
# Hello, wIZI+  -> score: 154
# Hello, wJZI+  -> score: 153
# Hello, wKZI+  -> score: 152
# Hello, wLZI+  -> score: 151
# Hello, wMZI+  -> score: 150
# Hello, wNZI+  -> score: 149
# Hello, wOZI+  -> score: 148
# Hello, wPZI+  -> score: 147
# Hello, wQZI+  -> score: 146
# Hello, wRZI+  -> score: 145
# Hello, wSZI+  -> score: 144
# Hello, wTZI+  -> score: 143
# Hello, wUZI+  -> score: 142
# Hello, wVZI+  -> score: 141
# Hello, wWZI+  -> score: 140
# Hello, wXZI+  -> score: 139
# Hello, wYZI+  -> score: 138
# Hello, wZZI+  -> score: 137
# Hello, w[ZI+  -> score: 136
# Hello, w\ZI+  -> score: 135
# Hello, w]ZI+  -> score: 134
# Hello, w^ZI+  -> score: 133
# Hello, w_ZI+  -> score: 132
# Hello, w`ZI+  -> score: 131
# Hello, waZI+  -> score: 130
# Hello, wbZI+  -> score: 129
# Hello, wcZI+  -> score: 128
# Hello, wdZI+  -> score: 127
# Hello, weZI+  -> score: 126
# Hello, wfZI+  -> score: 125
# Hello, wgZI+  -> score: 124
# Hello, whZI+  -> score: 123
# Hello, wiZI+  -> score: 122
# Hello, wjZI+  -> score: 121
# Hello, wkZI+  -> score: 120
# Hello, wlZI+  -> score: 119
# Hello, wmZI+  -> score: 118
# Hello, wnZI+  -> score: 117
# Hello, woZI+  -> score: 116
# Hello, wo[I+  -> score: 115
# Hello, wo\I+  -> score: 114
# Hello, wo]I+  -> score: 113
# Hello, wo^I+  -> score: 112
# Hello, wo_I+  -> score: 111
# Hello, wo`I+  -> score: 110
# Hello, woaI+  -> score: 109
# Hello, wobI+  -> score: 108
# Hello, wocI+  -> score: 107
# Hello, wodI+  -> score: 106
# Hello, woeI+  -> score: 105
# Hello, wofI+  -> score: 104
# Hello, wogI+  -> score: 103
# Hello, wohI+  -> score: 102
# Hello, woiI+  -> score: 101
# Hello, wojI+  -> score: 100
# Hello, wokI+  -> score: 99
# Hello, wolI+  -> score: 98
# Hello, womI+  -> score: 97
# Hello, wonI+  -> score: 96
# Hello, wooI+  -> score: 95
# Hello, wopI+  -> score: 94
# Hello, woqI+  -> score: 93
# Hello, worI+  -> score: 92
# Hello, worJ+  -> score: 91
# Hello, worK+  -> score: 90
# Hello, worL+  -> score: 89
# Hello, worM+  -> score: 88
# Hello, worN+  -> score: 87
# Hello, worO+  -> score: 86
# Hello, worP+  -> score: 85
# Hello, worQ+  -> score: 84
# Hello, worR+  -> score: 83
# Hello, worS+  -> score: 82
# Hello, worT+  -> score: 81
# Hello, worU+  -> score: 80
# Hello, worV+  -> score: 79
# Hello, worW+  -> score: 78
# Hello, worX+  -> score: 77
# Hello, worY+  -> score: 76
# Hello, worZ+  -> score: 75
# Hello, wor[+  -> score: 74
# Hello, wor\+  -> score: 73
# Hello, wor]+  -> score: 72
# Hello, wor^+  -> score: 71
# Hello, wor_+  -> score: 70
# Hello, wor`+  -> score: 69
# Hello, wora+  -> score: 68
# Hello, worb+  -> score: 67
# Hello, worc+  -> score: 66
# Hello, word+  -> score: 65
# Hello, wore+  -> score: 64
# Hello, worf+  -> score: 63
# Hello, worg+  -> score: 62
# Hello, worh+  -> score: 61
# Hello, wori+  -> score: 60
# Hello, worj+  -> score: 59
# Hello, work+  -> score: 58
# Hello, worl+  -> score: 57
# Hello, worl,  -> score: 56
# Hello, worl-  -> score: 55
# Hello, worl.  -> score: 54
# Hello, worl/  -> score: 53
# Hello, worl0  -> score: 52
# Hello, worl1  -> score: 51
# Hello, worl2  -> score: 50
# Hello, worl3  -> score: 49
# Hello, worl4  -> score: 48
# Hello, worl5  -> score: 47
# Hello, worl6  -> score: 46
# Hello, worl7  -> score: 45
# Hello, worl8  -> score: 44
# Hello, worl9  -> score: 43
# Hello, worl:  -> score: 42
# Hello, worl;  -> score: 41
# Hello, worl<  -> score: 40
# Hello, worl=  -> score: 39
# Hello, worl>  -> score: 38
# Hello, worl?  -> score: 37
# Hello, worl@  -> score: 36
# Hello, worlA  -> score: 35
# Hello, worlB  -> score: 34
# Hello, worlC  -> score: 33
# Hello, worlD  -> score: 32
# Hello, worlE  -> score: 31
# Hello, worlF  -> score: 30
# Hello, worlG  -> score: 29
# Hello, worlH  -> score: 28
# Hello, worlI  -> score: 27
# Hello, worlJ  -> score: 26
# Hello, worlK  -> score: 25
# Hello, worlL  -> score: 24
# Hello, worlM  -> score: 23
# Hello, worlN  -> score: 22
# Hello, worlO  -> score: 21
# Hello, worlP  -> score: 20
# Hello, worlQ  -> score: 19
# Hello, worlR  -> score: 18
# Hello, worlS  -> score: 17
# Hello, worlT  -> score: 16
# Hello, worlU  -> score: 15
# Hello, worlV  -> score: 14
# Hello, worlW  -> score: 13
# Hello, worlX  -> score: 12
# Hello, worlY  -> score: 11
# Hello, worlZ  -> score: 10
# Hello, worl[  -> score: 9
# Hello, worl\  -> score: 8
# Hello, worl]  -> score: 7
# Hello, worl^  -> score: 6
# Hello, worl_  -> score: 5
# Hello, worl`  -> score: 4
# Hello, worla  -> score: 3
# Hello, worlb  -> score: 2
# Hello, worlc  -> score: 1
# Hello, world  -> score: 0

# %%
print()
print("*************Hill climbing****************")
print("steps:{}, best solution:'{}', best score:{}".format(iterations,best_sol,best_score))
# Out:
# *************Hill climbing****************
# steps:385, best solution:'Hello, world', best score:0

# %% [markdown]
# ## 3. Simulated annealing
# The idea of the <em>simulated annealing</em> is borrowed from physics. In metalurgical annealing we heat a metal (alloy) to a very high temperature, the crystal bonds break, and the atoms diffuse more freely. If we cool it slowly, the atoms tend to form more regular crystals producing an alloy with the low termodynamics energy.
#
# <img style="height:250px;float:right;padding:4px;" src="images/sim_annealing.jpg" >
#
# In the <em>simulated annealing</em> algorithm we set the initial temperature very high, and then we generate a single random neighbor of the current solution. The fitness of this neihgbor can be better or worse that that of the current solution. When the temperature is high, the probability of selecting worse solution is higher. This allows to better explore the search space and get out of the local minimum. The temperature gradually decreases, and so at the end we do not accept worse solutions.
#
# The criterion of accepting ''bad'' solutions:
#
# $p=e^{\frac{-\Delta F}{T}}>R(0,1)$
#
# where $T$ is the current temperature, $R(0,1)$ is a random number between $0$ and $1$, and $\Delta F$ is the difference between the fitness score of new solution and the old solution.
#
# Since the temperature $T$ (the willingness to accept a worse solution) starts very high,
# the exponent will be close to 0, and $p$ will almost be 1. As the temperature decreases, the difference between the new fitness score and the old one becomes more important - a bigger difference leads to a lower probability, so the
# algorithm will not accept solutions which do not improve fitness - converging to a local minimum after exploring a large global search space.

# %%
import math

def annealing_optimize(start_sol, fitness_function, T=10000.0, cool=0.95, step=1):    
    sol = start_sol
    iterations = 0
    
    # Graduate cooling
    while T > 0.01: 
        score = fitness_function(sol)
        
        # Choose one of spots randomly
        i = random.randint(0, len(sol) - 1)

        # Choose rand direction to change the character at position i
        dir = random.randint(-step, step)

        change = ord(sol[i]) + dir
        # out of domain
        if change > 122 or change < 32:
            continue
    
        iterations += 1
        
        # Create a new solution with one of the characters changed
        new_sol = sol[:i] + chr(change) + sol[i+1:]

        # Calculate the new cost
        new_score = fitness_function(new_sol)        

        # Does it make the probability cutoff?
        p = pow(math.e, -(new_score - score) / T)
        
        if new_score < score or p > random.random() :
            sol = new_sol
            score = new_score
            if print_steps:
                print(sol, "-> score:", score)       
        
        if score == 0:
            break
            
        # Decrease the temperature
        T = T * cool
    
    return (score, sol, iterations)

# now test
rand_str = get_random_string(len(s), alphabet)
best_score, best_sol, iterations = annealing_optimize(rand_str, string_fitness,
                                          T=204800.0, cool=0.999, step=1)
# Out:
# 04sg5?x$WXF2 -> score: 471
# 03sg5?x$WXF2 -> score: 472
# 03sg5?w$WXF2 -> score: 471
# 03sg5?w$WXG2 -> score: 470
# 03sg5?w$WXG2 -> score: 470
# 03sg5@w$WXG2 -> score: 471
# 03sg5@w#WXG2 -> score: 472
# 03sf5@w#WXG2 -> score: 473
# 03sf5@w#VXG2 -> score: 474
# 02sf5@w#VXG2 -> score: 475
# 02sf5@w#VXG2 -> score: 475
# 02sf4@w#VXG2 -> score: 476
# 02tf4@w#VXG2 -> score: 477
# 02tf4@w#VXG2 -> score: 477
# 02tf4@w#VXG2 -> score: 477
# 02te4@w#VXG2 -> score: 478
# 02te4@w#VXG2 -> score: 478
# 02te4@w#VXG2 -> score: 478
# 02se4@w#VXG2 -> score: 477
# 02se5@w#VXG2 -> score: 476
# 02sf5@w#VXG2 -> score: 475
# 02sf5@w#VXG2 -> score: 475
# 02sf4@w#VXG2 -> score: 476
# 02sf4@w#VXG2 -> score: 476
# /2sf4@w#VXG2 -> score: 477
# /2sf4@x#VXG2 -> score: 478
# /2tf4@x#VXG2 -> score: 479
# /2tf4@x#VXG2 -> score: 479
# /2tf4@x#VXG2 -> score: 479
# /2tf4@x"VXG2 -> score: 480
# /2tf4@w"VXG2 -> score: 479
# /3tf4@w"VXG2 -> score: 478
# /3tf4@w"VXG2 -> score: 478
# /3tf4@w"VXG3 -> score: 477
# /3tf4@w"VXG2 -> score: 478
# /3tf4@w!VXG2 -> score: 479
# /3tf4@w!VXG2 -> score: 479
# /3tf4@w!WXG2 -> score: 478
# /3tf4@w!WXG2 -> score: 478
# /3tf4@w"WXG2 -> score: 477
# /3tf4@w"WXG2 -> score: 477
# /3te4@w"WXG2 -> score: 478
# /3te4@w"WXG2 -> score: 478
# /3te5@w"WXG2 -> score: 477
# /3te5@w"WXG1 -> score: 478
# 03te5@w"WXG1 -> score: 477
# 71ol/Ev Z_G6 -> score: 457
# 71ol/Eu Z_G6 -> score: 456
# 71ol/Du Z_G6 -> score: 455
# 71nl/Du Z_G6 -> score: 454
# 71nl/Du Z_G6 -> score: 454
# 71nl/Du Y_G6 -> score: 455
# 71nl/Du Y_G6 -> score: 455
# 71nl/Dt Y_G6 -> score: 454
# 71nl/Dt Y_G6 -> score: 454
# 70nl/Dt Y_G6 -> score: 455
# 70nl/Et Y_G6 -> score: 456
# 70nl.Et Y_G6 -> score: 457
# 70nl.Es Y_G6 -> score: 456
# 70nl.Es Y_G6 -> score: 456
# 7/nl.Es Y_G6 -> score: 457
# 7/nl.Es Y`G6 -> score: 456
# 7/nl.Es Y`G5 -> score: 457
# 7/nl.Es Y`G5 -> score: 457
# 7/ml.Es Y`G5 -> score: 456
# 6/ml.Es Y`G5 -> score: 457
# 6/ml.Es Y`G4 -> score: 458
# 6/ml/Es Y`G4 -> score: 457
# 6/ml/Es Y`G3 -> score: 458
# 6/nl/Es Y`G3 -> score: 459
# 7/nl/Es Y`G3 -> score: 458
# 7/nl/Fs Y`G3 -> score: 459
# 7.nl/Fs Y`G3 -> score: 460
# 7-nl/Fs Y`G3 -> score: 461
# 7-nl/Fr Y`G3 -> score: 460
# 7-nk/Fr Y`G3 -> score: 461
# 7-nk/Fr Y`G3 -> score: 461
# 8-nk/Fr Y`G3 -> score: 460
# 8-nl/Fr Y`G3 -> score: 459
# 7-nl/Fr Y`G3 -> score: 460
# 7-nl/Fr Y`G3 -> score: 460
# 7-nl/Fr Y`F3 -> score: 461
# 7-nl/Fr Y`F3 -> score: 461
# 7-nl/Fr Y`F3 -> score: 461
# 7-nl/Fq Y`F3 -> score: 460
# 7-nl/Fq!Y`F3 -> score: 459
# 7-nl/Fr!Y`F3 -> score: 460
# 7-nl/Gr!Y`F3 -> score: 461
# 8-nl/Gr!Y`F3 -> score: 460
# 8-nl/Gq!Y`F3 -> score: 459
# 8-nl/Fq!Y`F3 -> score: 458
# 8-nl/Fq!Y`F2 -> score: 459
# 8-nl/Fq!Y`F2 -> score: 459
# 8-nl/Fq!Y_F2 -> score: 460
# 8-nl/Fq!Y_F2 -> score: 460
# 8-ml/Fq!Y_F2 -> score: 459
# 8-ml/Fq!Y_G2 -> score: 458
# 8-ml/Eq!Y_G2 -> score: 457
# 8-nl/Eq!Y_G2 -> score: 458
# 8-nl/Eq!Y^G2 -> score: 459
# 8-nl/Eq!Y^G2 -> score: 459
# 8-nl/Eq!Y^G2 -> score: 459
# 8-nl/Fq!Y^G2 -> score: 460
# 8-nl/Fq!Y^G2 -> score: 460
# 7-nl/Fq!Y^G2 -> score: 461
# 7-nl/Eq!Y^G2 -> score: 460
# 7-nl/Eq!Y^G2 -> score: 460
# 7-nl/Eq!Y^G2 -> score: 460
# 7-nl/Eq Y^G2 -> score: 461
# 7-nl/Eq Y^G2 -> score: 461
# 7-nl/Eq Y_G2 -> score: 460
# 7-nl/Eq!Y_G2 -> score: 459
# 7-nl.Eq!Y_G2 -> score: 460
# 7,nl.Eq!Y_G2 -> score: 461
# 7,nm.Eq!Y_G2 -> score: 462
# 7,nm.Eq!Y_G2 -> score: 462
# 7,nm.Eq!Y_G2 -> score: 462
# 7,om.Eq!Y_G2 -> score: 463
# 7,om.Eq!Y_G2 -> score: 463
# 7,on.Eq!Y_G2 -> score: 464
# 8,on.Eq!Y_G2 -> score: 463
# 8,on.Eq!Y_G2 -> score: 463
# 8,nn.Eq!Y_G2 -> score: 462
# 8,nn.Ep!Y_G2 -> score: 461
# 8,nn.Ep!Y_G2 -> score: 461
# 8,nn.Ep!Y_G2 -> score: 461
# 8,nn.Ep!Y_G3 -> score: 460
# 8,nn.Ep!Y_G3 -> score: 460
# 8,nn.Ep!Y_G3 -> score: 460
# 8,nn.Ep!Y_H3 -> score: 459
# 8,nn.Fp!Y_H3 -> score: 460
# 8,nn.Fp Y_H3 -> score: 461
# 8,nn.Fp Y_H3 -> score: 461
# 8,nn.Ep Y_H3 -> score: 460
# 7,nn.Ep Y_H3 -> score: 461
# 7,nn.Fp Y_H3 -> score: 462
# 7,nn.Fp Y_H3 -> score: 462
# 7,nn.Fp Y`H3 -> score: 461
# 8,nn.Fp Y`H3 -> score: 460
# 8,nn.Fq Y`H3 -> score: 461
# 8,nn.Fq Y`H2 -> score: 462
# 8,nn.Fq Y`H2 -> score: 462
# 8,nn.Fq Y`H2 -> score: 462
# 8,nn.Fq Y`H2 -> score: 462
# 9,nn.Fq Y`H2 -> score: 461
# 9,nn.Fq Y_H2 -> score: 462
# 9,nn.Fq Y_H2 -> score: 462
# 9,nn.Fq Y_H2 -> score: 462
# 9,nn.Fr Y_H2 -> score: 463
# 9,nn.Fs Y_H2 -> score: 464
# 9,nn.Fs Z_H2 -> score: 463
# 9,nn/Fs Z_H2 -> score: 462
# 9,nn/Fs Z_H2 -> score: 462
# 9,no/Fs Z_H2 -> score: 463
# 9,no/Fs Z_H2 -> score: 463
# 9,no/Fs Z_H2 -> score: 463
# 9+no/Fs Z_H2 -> score: 464
# 9+no/Fs Z_H2 -> score: 464
# 9+no/Fs Z`H2 -> score: 463
# 9+no/Fs Z`H2 -> score: 463
# 9+no.Fs Z`H2 -> score: 464
# 9+no.Fs Z`H2 -> score: 464
# 8+no.Fs Z`H2 -> score: 465
# 8+no.Fs!Z`H2 -> score: 464
# 8+no.Fs!Z`G2 -> score: 465
# 8+no.Fs!Z`G2 -> score: 465
# 8*no.Fs!Z`G2 -> score: 466
# 8*no.Gs!Z`G2 -> score: 467
# 8*no.Gs Z`G2 -> score: 468
# 8*no.Gs Z`G3 -> score: 467
# 8*no.Gs [`G3 -> score: 466
# 8)no.Gs [`G3 -> score: 467
# 8)no.Gs \`G3 -> score: 466
# 8)no.Gs \`F3 -> score: 467
# 9)no.Gs \`F3 -> score: 466
# 8)no.Gs \`F3 -> score: 467
# 8)no.Gs \`F3 -> score: 467
# 8)no.Hs \`F3 -> score: 468
# 8)no/Hs \`F3 -> score: 467
# 8)no/Hs \`F3 -> score: 467
# 8)no0Hs \`F3 -> score: 466
# 8)no0Hs \`F3 -> score: 466
# 8)no0Hs \
# </pv3Nw*YYI3 -> score: 469
# </pv3Nw*YYI3 -> score: 469
# </pv3Nw*YYI3 -> score: 469
# </pv3Nw*YYI3 -> score: 469
# </pv3Nw*YYI2 -> score: 470
# </pv3Nw*YYI2 -> score: 470
# </pv3Nw)YYI2 -> score: 471
# </pv3Nw)YYH2 -> score: 472
# </pv3Nw)YYH2 -> score: 472
# </pu3Nw)YYH2 -> score: 471
# </pu3Nw)YYH2 -> score: 471
# </pu3Nw)YYH2 -> score: 471
# </pu3Nw)YYI2 -> score: 470
# </pu3Nw)XYI2 -> score: 471
# </pu3Nw)YYI2 -> score: 470
# </pu3Nw)YYI2 -> score: 470
# </pu3Nw)YYI2 -> score: 470
# ;/pu3Nw)YYI2 -> score: 471
# ;/pu3Nw)YYH2 -> score: 472
# ;.pu3Nw)YYH2 -> score: 473
# ;.pu2Nw)YYH2 -> score: 474
# ;.pu2Nw)YYH2 -> score: 474
# ;.pu2Mw)YYH2 -> score: 473
# ;/pu2Mw)YYH2 -> score: 472
# ;/pu2Lw)YYH2 -> score: 471
# ;/pt2Lw)YYH2 -> score: 470
# ;/pt2Lw)YZH2 -> score: 469
# ;.pt2Lw)YZH2 -> score: 470
# ;.pt2Lw*YZH2 -> score: 469
# ;.pt2Lw*YZH2 -> score: 469
# ;.pt2Lw*YZH2 -> score: 469
# ;.pt2Lw*XZH2 -> score: 470
# ;.qt2Lw*XZH2 -> score: 471
# ;.qt2Lw*XZH3 -> score: 470
# ;.qt2Lw*XZH3 -> score: 470
# ;.qt3Lw*XZH3 -> score: 469
# ;.qt4Lw*XZH3 -> score: 468
# ;.qt4Lw*XZG3 -> score: 469
# ;/qt4Lw*XZG3 -> score: 468
# ;/qt4Lv*XZG3 -> score: 467
# ;/qt4Kv*XZG3 -> score: 466
# ;/qt4Kv*XZG3 -> score: 466
# ;/qt4Kv*XZG2 -> score: 467
# ;.qt4Kv*XZG2 -> score: 468
# <.qt4Kv*XZG2 -> score: 467
# <.qt4Ku*XZG2 -> score: 466
# <.qt4Ku*XZF2 -> score: 467
# <.qt4Ku+XZF2 -> score: 466
# <.qt4Ku+XZE2 -> score: 467
# <.pt4Ku+XZE2 -> score: 466
# <.pt4Ku+XZE2 -> score: 466
# <.pt4Ku+XZF2 -> score: 465
# <.pt4Ku+XZF1 -> score: 466
# =.pt4Ku+XZF1 -> score: 465
# =.pt4Ku,XZF1 -> score: 464
# =.pt4Ku,WZF1 -> score: 465
# =.pt4Ku,WZF1 -> score: 465
# =.pt4Ku,WZF1 -> score: 465
# =.pt4Kt,WZF1 -> score: 464
# =.pt5Kt,WZF1 -> score: 463
# =.pt5Kt,W[F1 -> score: 462
# =.pt5Kt,W[E1 -> score: 463
# =.pu5Kt,W[E1 -> score: 464
# =.pu5Kt,W[E1 -> score: 464
# =/pu5Kt,W[E1 -> score: 463
# =/pu5Kt,V[E1 -> score: 464
# =/pu5Kt,V[E1 -> score: 464
# =/pu5Kt,VZE1 -> score: 465
# =/pu5Kt,VZE1 -> score: 465
# 62fk9Iv)UVF4 -> score: 463
# 62fk9Iv)UVF4 -> score: 463
# 62fk:Iv)UVF4 -> score: 462
# 62fj:Iv)UVF4 -> score: 463
# 62fj:Iw)UVF4 -> score: 464
# 62fj:Iw)UVF4 -> score: 464
# 62fj:Iw)VVF4 -> score: 463
# 62fj:Iv)VVF4 -> score: 462
# 63fj:Iv)VVF4 -> score: 461
# 63fj:Iv)UVF4 -> score: 462
# 63fk:Iv)UVF4 -> score: 461
# 63fk:Iv)UVG4 -> score: 460
# 63fj:Iv)UVG4 -> score: 461
# 63fj:Hv)UVG4 -> score: 460
# 63fj:Hv)UVG4 -> score: 460
# 63fj:Hv)UVG4 -> score: 460
# 73fj:Hv)UVG4 -> score: 459
# 73fj:Hv)UWG4 -> score: 458
# 73ej:Hv)UWG4 -> score: 459
# 73ej:Hv)UWG4 -> score: 459
# 73ej:Hu)UWG4 -> score: 458
# 73ek:Hu)UWG4 -> score: 457
# 73ek:Hu)UWG4 -> score: 457
# 73ek:Hu)UWG3 -> score: 458
# 73ek:Hu)UWG3 -> score: 458
# 73ek:Hu)UWF3 -> score: 459
# 73ek:Hu(UWF3 -> score: 460
# 73ek:Hv(UWF3 -> score: 461
# 73ek:Hv(UVF3 -> score: 462
# 73dk:Hv(UVF3 -> score: 463
# 73dk:Hv(UVF3 -> score: 463
# 73dk:Hv(UVF3 -> score: 463
# 73dk:Hv(UVF3 -> score: 463
# 73dk:Hw(UVF3 -> score: 464
# 73dk:Hw(UUF3 -> score: 465
# 73dk:Hw(UUF3 -> score: 465
# 73ck:Hw(UUF3 -> score: 466
# 73ck:Hw(UUF3 -> score: 466
# 73ck;Hw(UUF3 -> score: 465
# 73ck;Hw(UUF3 -> score: 465
# 73ck;Hw(VUF3 -> score: 464
# 73ck;Hw(VUF4 -> score: 463
# 73dk;Hw(VUF4 -> score: 462
# 73dk;Hw(UUF4 -> score: 463
# 73dk;Hw(UUF4 -> score: 463
# 73dk;Hw(UUG4 -> score: 462
# 73dk;Hw(UUH4 -> score: 461
# 73dk;Hw(UUH4 -> score: 461
# 73dk;Iw(UUH4 -> score: 462
# 73dk;Iw(UUH4 -> score: 462
# 73dk;Iw(UUH4 -> score: 462
# 73dk;Iw(UUH4 -> score: 462
# 73dk;Jw(UUH4 -> score: 463
# 73dk;Jw(UUH4 -> score: 463
# 73dk;Jw(UUH4 -> score: 463
# 73dk;Jw(UUH4 -> score: 463
# 73dk;Jw(UUH4 -> score: 463
# 73dk;Jw(UUH4 -> score: 463
# 73dk;Jw(UUH3 -> score: 464
# 73dk;Jw(UUH3 -> score: 464
# 73dk:Jw(UUH3 -> score: 465
# 73dk:Iw(UUH3 -> score: 464
# 73dk:Iw(UUH3 -> score: 464
# 73dk:Iw(UUH3 -> score: 464
# 73dk:Iw(UUI3 -> score: 463
# 73dk:Iw)UUI3 -> score: 462
# 73dk:Hw)UUI3 -> score: 461
# 73dk:Hw)UTI3 -> score: 462
# 73dj:Hw)UTI3 -> score: 463
# 73cj:Hw)UTI3 -> score: 464
# 73cj:Hw)UTI3 -> score: 464
# 73cj:Hw)UTI3 -> score: 464
# 73cj;Hw)UTI3 -> score: 463
# 73cj;Hw)UTI3 -> score: 463
# 73cj;Hw)UTI3 -> score: 463
# 73cj;Hw(UTI3 -> score: 464
# 63cj;Hw(UTI3 -> score: 465
# 63cj;Hv(UTI3 -> score: 464
# 73cj;Hv(UTI3 -> score: 463
# 73cj;Hv(UTI3 -> score: 463
# 73cj;Hv(UTH3 -> score: 464
# 73cj;Hv(UTH3 -> score: 464
# 63cj;Hv(UTH3 -> score: 465
# 63cj;Hv(UTH3 -> score: 465
# 63cj;Hv(UTH3 -> score: 465
# 63bj;Hv(UTH3 -> score: 466
# 63bj;Hv(UTH3 -> score: 466
# 63bj<Hv(UTH3 -> score: 465
# 63bj<Hv)UTH3 -> score: 464
# 63bj<Hw)UTH3 -> score: 465
# 63bj<Hw)UTH3 -> score: 465
# 63bj<Hw)UUH3 -> score: 464
# 63bj<Hw)VUH3 -> score: 463
# 63bj<Hw)UUH3 -> score: 464
# 63bj<Hw)UUH3 -> score: 464
# 63bj<Hw)UUH3 -> score: 464
# 64bj<Hw)UUH3 -> score: 463
# 64bi<Hw)UUH3 -> score: 464
# 64bi<Hw)UUH3 -> score: 464
# 64bi<Hw)UUH3 -> score: 464
# 64bi;Hw)UUH3 -> score: 465
# 64bi;Hw)UUH3 -> score: 465
# 64ci;Hw)UUH3 -> score: 464
# 64di;Hw)UUH3 -> score: 463
# 64di;Hw)UUH3 -> score: 463
# 64di;Hw(UUH3 -> score: 464
# 64di;Hw(UUH3 -> score: 464
# 63di;Hw(UUH3 -> score: 465
# 63di;Hw(UUH3 -> score: 465
# 64di;Hw(UUH3 -> score: 464
# 64di;Hw(UUH3 -> score: 464
# 64di;Hw(UUH3 -> score: 464
# 64di;Hw(UUH3 -> score: 464
# 64di;Hw(UUH3 -> score: 464
# 64di;Hw(UUH3 -> score: 464
# 64di;Hw(UUH3 -> score: 464
# 64di;Hw(UUH3 -> score: 464
# 64di;Hw(UUH3 -> score: 464
# 64di;Hw(UUH3 -> score: 464
# 64ei;Hw(UUH3 -> score: 463
# 64ei;Hv(UUH3 -> score: 462
# 64ei;Hv(UUH3 -> score: 462
# 64ei;Hv(UUH3 -> score: 462
# 65ei;Hv(UUH3 -> score: 461
# 65ei;Hv'UUH3 -> score: 462
# 65ej;Hv'UUH3 -> score: 461
# 65ej;Hv'UUH3 -> score: 461
# 65ek;Hv'UUH3 -> score: 460
# 65ek;Hv'UTH3 -> score: 461
# 65ek;Gv'UTH3 -> score: 460
# 65ek;Gv'USH3 -> score: 461
# 65ek;Gv'USH3 -> score: 461
# 65ej;Gv'USH3 -> score: 462
# 65ej;Gv'USH3 -> score: 462
# 65ej;Gv'VSH3 -> score: 461
# 65ej;Gv'VSH3 -> score: 461
# 65ej;Gv'VSH3 -> score: 461
# 65ej;Gv(VSH3 -> score: 460
# 65ej;Gv(VSH3 -> score: 460
# 65dj;Gv(VSH3 -> score: 461
# 65dj<Gv(VSH3 -> score: 460
# 65dj<Gv(VSH2 -> score: 461
# 65dj<Gv(VSH1 -> score: 462
# 64dj<Gv(VSH1 -> score: 463
# 64dj<Gv)VSH1 -> score: 462
# 65dj<Gv)VSH1 -> score: 461
# 65dj<Gv)WSH1 -> score: 460
# 65dj<Gw)WSH1 -> score: 461
# 75dj<Gw)WSH1 -> score: 460
# 75dj<Gw)WSG1 -> score: 461
# 85dj<Gw)WSG1 -> score: 460
# 85dk<Gw)WSG1 -> score: 459
# 85dk<Gw)WSG1 -> score: 459
# 85dk<Gw(WSG1 -> score: 460
# 85dk;Gw(WSG1 -> score: 461
# 85dk:Gw(WSG1 -> score: 462
# 85dk:Gw(XSG1 -> score: 461
# 85dl:Gw(XSG1 -> score: 460
# 75dl:Gw(XSG1 -> score: 461
# 65dl:Gw(XSG1 -> score: 462
# 65cl:Gw(XSG1 -> score: 463
# 65cl:Gw(XSG1 -> score: 463
# 64cl:Gw(XSG1 -> score: 464
# 64cl:Gv(XSG1 -> score: 463
# 64cl:Gv)XSG1 -> score: 462
# 64cl:Gv)XSG1 -> score: 462
# 64cl:Gv)XSF1 -> score: 463
# 64bl:Gv)XSF1 -> score: 464
# 64bl:Gv)YSF1 -> score: 463
# 64bl:Gv)YSF1 -> score: 463
# 64bl;Gv)YSF1 -> score: 462
# 64bl;Gv)YSF1 -> score: 462
# 64bl;Gv(YSF1 -> score: 463
# 64bl;Gv(YSF1 -> score: 463
# 64bl;Gv(XSF1 -> score: 464
# 54bl;Gv(XSF1 -> score: 465
# 44bl;Gv(XSF1 -> score: 466
# 44bl;Gv(XSF1 -> score: 466
# 44bl;Gv(XSF1 -> score: 466
# 44bl;Gv(YSF1 -> score: 465
# 44bl:Gv(YSF1 -> score: 466
# 44bl:Gv(YSF1 -> score: 466
# 44bl9Gv(YSF1 -> score: 467
# 44bl9Gv(YSF1 -> score: 467
# 44bl9Gv(YSF1 -> score: 467
# 44bl9Gv(YSF1 -> score: 467
# 44bl9Gv(XSF1 -> score: 468
# 44bl9Gv(XSF1 -> score: 468
# 44bl9Gv'XSF1 -> score: 469
# 44bl9Gv'XSF0 -> score: 470
# 44bl8Gv'XSF0 -> score: 471
# 44bl8Gv'XSF0 -> score: 471
# 54bl8Gv'XSF0 -> score: 470
# 54bl8Gu'XSF0 -> score: 469
# 44bl8Gu'XSF0 -> score: 470
# 44bl8Gu'XSF1 -> score: 469
# 44bl8Gu'WSF1 -> score: 470
# 44bl8Gu'WSF1 -> score: 470
# 44bl8Gu'WSF1 -> score: 470
# 44bl8Fu'WSF1 -> score: 469
# 44bl9Fu'WSF1 -> score: 468
# 44bl9Fu'WSF1 -> score: 468
# 44bl:Fu'WSF1 -> score: 467
# 44al:Fu'WSF1 -> score: 468
# 44al:Fu'WRF1 -> score: 469
# 44bl:Fu'WRF1 -> score: 468
# 44bl:Fu'WRF1 -> score: 468
# 44bl:Fu'WRF0 -> score: 469
# 34bl:Fu'WRF0 -> score: 470
# 34bl:Fu'WSF0 -> score: 469
# 34bl:Fu'WSF0 -> score: 469
# 34bl9Fu'WSF0 -> score: 470
# 34bl9Fu(WSF0 -> score: 469
# 34cl9Fu(WSF0 -> score: 468
# 34cl9Fu(WSF0 -> score: 468
# 24cl9Fu(WSF0 -> score: 469
# 24cl9Fu(WSF0 -> score: 469
# 24cm9Fu(WSF0 -> score: 470
# 24cm9Fu(WSF0 -> score: 470
# 24cm9Eu(WSF0 -> score: 469
# 24cm9Eu(WSF1 -> score: 468
# 24cm9Eu(WSF1 -> score: 468
# 24cm9Eu(WSF2 -> score: 467
# 24cm9Eu(WSF2 -> score: 467
# 24cm9Eu(WSF2 -> score: 467
# 23cm9Eu(WSF2 -> score: 468
# 23cm9Eu(WSF2 -> score: 468
# 23cl9Eu(WSF2 -> score: 467
# 23cl9Eu(WRF2 -> score: 468
# 23cm9Eu(WRF2 -> score: 469
# 33cm9Eu(WRF2 -> score: 468
# 33cm9Eu(WRF1 -> score: 469
# 33cn9Eu(WRF1 -> score: 470
# 33cn9Eu(WRF0 -> score: 471
# 33cn9Eu(WRF0 -> score: 471
# 33cn8Eu(WRF0 -> score: 472
# 33cn8Du(WRF0 -> score: 471
# 33cn8Du(WRF0 -> score: 471
# 33cn8Du)WRF0 -> score: 470
# 33bn8Du)WRF0 -> score: 471
# 33bn8Du)WRF0 -> score: 471
# 33bn8Du)WRF0 -> score: 471
# 33bn8Du)WRF1 -> score: 470
# 33bn8Eu)WRF1 -> score: 471
# 33bn8Eu(WRF1 -> score: 472
# 33bn8Eu(WRF1 -> score: 472
# 33bn8Eu(WSF1 -> score: 471
# 33bn8Eu(WSF1 -> score: 471
# 33bn8Eu(WSF2 -> score: 470
# 43bn8Eu(WSF2 -> score: 469
# 43bn8Eu(WSF2 -> score: 469
# 43bn8Ev(WSF2 -> score: 470
# 43bn8Fv(WSF2 -> score: 471
# 43bn8Fv(WSG2 -> score: 470
# 43bn8Fv(WSG2 -> score: 470
# 43bn8Fv(WSG2 -> score: 470
# 43bn9Fv(WSG2 -> score: 469
# 43bn9Fv(WSG2 -> score: 469
# 43bn9Fv(WSG2 -> score: 469
# 43bn9Gv(WSG2 -> score: 470
# 43bn9Gv(WSG2 -> score: 470
# 43bn9Gv(XSG2 -> score: 469
# 43bn9Gw(XSG2 -> score: 470
# 43bn9Gw(XSG2 -> score: 470
# 53bn9Gw(XSG2 -> score: 469
# 63bn9Gw(XSG2 -> score: 468
# 63bn9Gw(YSG2 -> score: 467
# 63bn9Gw(YTG2 -> score: 466
# 63bn9Gw)YTG2 -> score: 465
# 63bn9Gw)YTG2 -> score: 465
# 63bn9Gw)YTG2 -> score: 465
# 63bn9Gw)YTG2 -> score: 465
# 63bn8Gw)YTG2 -> score: 466
# 64bn8Gw)YTG2 -> score: 465
# 64bn7Gw)YTG2 -> score: 466
# 63bn7Gw)YTG2 -> score: 467
# ...
# HeklI,Neor`d -> score: 115
# HeklI,Nfor`d -> score: 114
# HeklI,Nfor`d -> score: 114
# HeklI,Nfor`d -> score: 114
# HeklI,Nfor`d -> score: 114
# HeklI,Nfor`d -> score: 114
# HeklI,Nfor`d -> score: 114
# HeklI,Ngor`d -> score: 113
# HeklI,Mgor`d -> score: 112
# HeklJ,Mgor`d -> score: 111
# HeklJ,Mgor`d -> score: 111
# HeklJ,Lgor`d -> score: 110
# HeklJ,Lgor`d -> score: 110
# HeklJ,Lgor`d -> score: 110
# HeklJ,Lgorad -> score: 109
# HeklJ,Lgorad -> score: 109
# HeklJ,Lgorad -> score: 109
# HeklJ,Lgorad -> score: 109
# HeklJ,Lgorad -> score: 109
# HeklJ,Lgorad -> score: 109
# HeklJ,Lgorad -> score: 109
# HeklJ,Lgorad -> score: 109
# HeklK,Lgorad -> score: 108
# HeklK,Lgorad -> score: 108
# HeklK,Lgorad -> score: 108
# HeklK,Lgorad -> score: 108
# HeklK,Lgorad -> score: 108
# HeklK,Lgorad -> score: 108
# HeklK,Lgorad -> score: 108
# HeklK,Lhorad -> score: 107
# HeklK,Lhorad -> score: 107
# HeklL,Lhorad -> score: 106
# HeklL,Lhorad -> score: 106
# HeklL,Lhorad -> score: 106
# HeklL,Lhorad -> score: 106
# HeklL,Lhorad -> score: 106
# HeklL,Lhorad -> score: 106
# HeklL,Lhorad -> score: 106
# HeklL,Khorad -> score: 105
# HeklL,Khorad -> score: 105
# HeklL,Khorad -> score: 105
# HeklL,Khorad -> score: 105
# HeklL,Khorad -> score: 105
# HeklL,Khorbd -> score: 104
# HellL,Khorbd -> score: 103
# HellL,Kiorbd -> score: 102
# HellL,Kiorbd -> score: 102
# HellL,Kiorbd -> score: 102
# HellL,Kiorbd -> score: 102
# HellL,Kiorbd -> score: 102
# HellL,Kiorcd -> score: 101
# HellL,Jiorcd -> score: 100
# HellL,Jiorcd -> score: 100
# HellL,Jiorcd -> score: 100
# HellL,Jiorcd -> score: 100
# HellM,Jiorcd -> score: 99
# HellM,Jiordd -> score: 98
# HellM,Jiordd -> score: 98
# HellM,Jiordd -> score: 98
# HellM,Jiored -> score: 97
# HellN,Jiored -> score: 96
# HellN+Jiored -> score: 97
# HellO+Jiored -> score: 96
# HellO+Jiored -> score: 96
# HellO+Jiorfd -> score: 95
# HellO+Jiorfd -> score: 95
# HellO+Jiorfd -> score: 95
# HellO,Jiorfd -> score: 94
# HellO,Jiorfd -> score: 94
# HellO,Jiorfd -> score: 94
# HellO,Jiorfd -> score: 94
# HellO,Jiorfd -> score: 94
# HellO,Jiorfd -> score: 94
# HellO,Jiorfd -> score: 94
# HellO,Jiorfd -> score: 94
# HellO,Jjorfd -> score: 93
# HellO,Jjorfd -> score: 93
# HellO,Jjorgd -> score: 92
# HellO,Jjorgd -> score: 92
# HellO,Jjorgd -> score: 92
# HellO,Jkorgd -> score: 91
# HellO,Jkorgd -> score: 91
# HellO,Jkorgd -> score: 91
# HellP,Jkorgd -> score: 90
# HellP,Jkorgd -> score: 90
# HellP,Jkorgd -> score: 90
# HellP,Jkorgd -> score: 90
# HellP,Jlorgd -> score: 89
# HellP,Jlorgd -> score: 89
# HellP,Ilorgd -> score: 88
# HellP,Ilorgd -> score: 88
# HellP,Imorgd -> score: 87
# HellP,Hmorgd -> score: 86
# HellP,Hmorgd -> score: 86
# HellP+Hmorgd -> score: 87
# HellP+Hmorgd -> score: 87
# HellP+Hmorgd -> score: 87
# HellP,Hmorgd -> score: 86
# HellP,Hmnrgd -> score: 87
# HellP,Hnnrgd -> score: 86
# HellP,Hnnrgd -> score: 86
# HellP,Hnnrfd -> score: 87
# HellP,Hnnrfd -> score: 87
# HellP,Hnnrfd -> score: 87
# HellQ,Hnnrfd -> score: 86
# HellQ,Honrfd -> score: 85
# HellQ,Hpnrfd -> score: 84
# HellQ,Hpnrfd -> score: 84
# HellQ,Hpnrfd -> score: 84
# HellQ,Hpnrgd -> score: 83
# HellQ,Hpnrgd -> score: 83
# HellQ,Hpnrhd -> score: 82
# HellQ,Hpnrhd -> score: 82
# HellQ,Hpnrhd -> score: 82
# HellQ,Hpnrhd -> score: 82
# HellQ,Hqnrhd -> score: 81
# HellQ,Hqnrhd -> score: 81
# HellQ,Hqnrhd -> score: 81
# HellQ,Hqnrhd -> score: 81
# HellQ,Hqnrhd -> score: 81
# HellQ,Hqnrhd -> score: 81
# HellQ,Hqnrhd -> score: 81
# HellQ,Hqorhd -> score: 80
# HellQ,Hrorhd -> score: 79
# HellQ,Hrorhd -> score: 79
# HellQ,Hrorhd -> score: 79
# HellQ,Hrorhd -> score: 79
# HellQ,Hrorhd -> score: 79
# HellQ,Hrorhd -> score: 79
# HellQ,Hsorhd -> score: 78
# HellQ,Hsorhd -> score: 78
# HellQ,Hsorhd -> score: 78
# HellR,Hsorhd -> score: 77
# HellR,Hsorhd -> score: 77
# HellR,Hsnrhd -> score: 78
# HellR,Hsnrhd -> score: 78
# HellR,Htnrhd -> score: 77
# HellR,Htnrhd -> score: 77
# HellR,Gtnrhd -> score: 76
# HellR,Gunrhd -> score: 75
# HellR,Gunrhd -> score: 75
# HellR,Gvnrhd -> score: 74
# HellR,Gvnrhd -> score: 74
# HellR,Gvnrhd -> score: 74
# HellR,Gvnrhd -> score: 74
# HellR,Gvnrhd -> score: 74
# HellR,Gvnrhd -> score: 74
# HellR,Gvnrhd -> score: 74
# HellR,Gvnrgd -> score: 75
# HfllR,Gvnrgd -> score: 76
# HfllR,Gvorgd -> score: 75
# HfllR,Gvorgd -> score: 75
# HfllR,Gvorgd -> score: 75
# HfllR,Gvorgd -> score: 75
# HfllS,Gvorgd -> score: 74
# HfllT,Gvorgd -> score: 73
# HfllT,Gvorgd -> score: 73
# HfllT,Gvorhd -> score: 72
# HfllT,Fvorhd -> score: 71
# HellT,Fvorhd -> score: 70
# HellT,Fvorhd -> score: 70
# HellT,Fvorhd -> score: 70
# HellT,Fvorhd -> score: 70
# HellT,Fvorhd -> score: 70
# HellT,Fvorid -> score: 69
# HellT,Fvorid -> score: 69
# HellT,Fvorjd -> score: 68
# HellT,Fvorjd -> score: 68
# HellU,Fvorjd -> score: 67
# HellU,Fvorjd -> score: 67
# HellU,Fvorjd -> score: 67
# HellU,Fvorjd -> score: 67
# HellU,Fvorjd -> score: 67
# HellU,Fvorjd -> score: 67
# HellV,Fvorjd -> score: 66
# HellV,Fvorjd -> score: 66
# HellV,Fvorjd -> score: 66
# HellV,Fvorkd -> score: 65
# HellV,Fvorkd -> score: 65
# HellV,Fvorld -> score: 64
# HellV,Fvorld -> score: 64
# HemlV,Fvorld -> score: 65
# HellV,Fvorld -> score: 64
# HellV,Fvorld -> score: 64
# HellV,Fvorld -> score: 64
# HellV,Fvorld -> score: 64
# HellV,Evorld -> score: 63
# HellV,Evorld -> score: 63
# HellW,Evorld -> score: 62
# HellW,Evorld -> score: 62
# HellW,Evorld -> score: 62
# HellX,Evorld -> score: 61
# HellX,Dvorld -> score: 60
# HellX,Dworld -> score: 59
# HellX,Dworld -> score: 59
# HellX,Dworld -> score: 59
# HellX,Dworld -> score: 59
# HellX,Dworld -> score: 59
# HellX,Cworld -> score: 58
# HellX,Cworld -> score: 58
# HellY,Cworld -> score: 57
# HellZ,Cworld -> score: 56
# HellZ,Cworld -> score: 56
# HellZ,Cworld -> score: 56
# HellZ,Cworld -> score: 56
# HellZ,Bworld -> score: 55
# HellZ,Bworld -> score: 55
# HellZ,Bworld -> score: 55
# HellZ,Bworld -> score: 55
# HellZ,Bworld -> score: 55
# HellZ,Bworld -> score: 55
# HellZ,Bworld -> score: 55
# HellZ,Bworld -> score: 55
# HellZ,Bworld -> score: 55
# HellZ,Aworld -> score: 54
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# HellZ,@world -> score: 53
# Hell[,@world -> score: 52
# Hell[,@world -> score: 52
# Hell[,@world -> score: 52
# Hell[,@world -> score: 52
# Hell[,@world -> score: 52
# Hell[,@world -> score: 52
# Hell[,@world -> score: 52
# Hell\,@world -> score: 51
# Hell\,@world -> score: 51
# Hell\,?world -> score: 50
# Hell\,?world -> score: 50
# Hell\,?world -> score: 50
# Hell\,?world -> score: 50
# Hell\,?world -> score: 50
# Hell\,?world -> score: 50
# Hell\,?world -> score: 50
# Hell\,?world -> score: 50
# Hell\,?world -> score: 50
# Helm\,?world -> score: 51
# Helm\,?world -> score: 51
# Helm\,?world -> score: 51
# Helm\,?world -> score: 51
# Helm],?world -> score: 50
# Helm],?woqld -> score: 51
# Helm],?woqld -> score: 51
# Helm],@woqld -> score: 52
# Helm],@woqld -> score: 52
# Helm],@woqld -> score: 52
# Helm],?woqld -> score: 51
# Helm],?woqld -> score: 51
# Helm],?woqld -> score: 51
# Helm],?woqld -> score: 51
# Helm],?woqld -> score: 51
# Hell],?woqld -> score: 50
# Hell],?woqld -> score: 50
# Hell],?woqld -> score: 50
# Hell],?woqld -> score: 50
# Hell],>woqld -> score: 49
# Hell],>woqld -> score: 49
# Hell],>woqld -> score: 49
# Hell],>woqld -> score: 49
# Hell^,>woqld -> score: 48
# Hell^,>woqld -> score: 48
# Hell^,>world -> score: 47
# Hell^,>world -> score: 47
# Hell^,=world -> score: 46
# Hell^,=world -> score: 46
# Hell^,=world -> score: 46
# Hell^,=world -> score: 46
# Hell^,=world -> score: 46
# Hell^,=world -> score: 46
# Hell^,=world -> score: 46
# Hell_,=world -> score: 45
# Hell_,=world -> score: 45
# Hell_,=world -> score: 45
# Hell_,=world -> score: 45
# Hell_,=world -> score: 45
# Hell_,=world -> score: 45
# Hell_,<world -> score: 44
# Hell_,<world -> score: 44
# Hell_,<world -> score: 44
# Hell_,<world -> score: 44
# Hell_,<world -> score: 44
# Hell_,<world -> score: 44
# Hell_,<world -> score: 44
# Hell_,;world -> score: 43
# Hell_,:world -> score: 42
# Hell_,:world -> score: 42
# Hell_,9world -> score: 41
# Hell_,9world -> score: 41
# Hell_,9world -> score: 41
# Hell_,8world -> score: 40
# Hell_,7world -> score: 39
# Hell`,7world -> score: 38
# Hell`,7world -> score: 38
# Hell`,7world -> score: 38
# Hella,7world -> score: 37
# Hella,7world -> score: 37
# Hella,7world -> score: 37
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hella,6world -> score: 36
# Hellb,6world -> score: 35
# Hellb,6world -> score: 35
# Hellb,6world -> score: 35
# Hellb,5world -> score: 34
# Hellb,5world -> score: 34
# Hellb,5world -> score: 34
# Hellb,5world -> score: 34
# Hellc,5world -> score: 33
# Hellc,4world -> score: 32
# Hellc,4world -> score: 32
# Hellc,3world -> score: 31
# Hellc,3world -> score: 31
# Hellc,3world -> score: 31
# Hellc,3world -> score: 31
# Hellc,2world -> score: 30
# Helld,2world -> score: 29
# Helld,2world -> score: 29
# Helld,2world -> score: 29
# Helld,2world -> score: 29
# Helle,2world -> score: 28
# Helle,2world -> score: 28
# Helle,1world -> score: 27
# Helle,1world -> score: 27
# Helle,1world -> score: 27
# Helle,1world -> score: 27
# Helle,1world -> score: 27
# Helle,1world -> score: 27
# Helle,1world -> score: 27
# Helle,1world -> score: 27
# Hellf,1world -> score: 26
# Hellf,1world -> score: 26
# Hellf,1world -> score: 26
# Hellf,1world -> score: 26
# Hellf,1world -> score: 26
# Hellf,1world -> score: 26
# Hellf,1world -> score: 26
# Hellf,1world -> score: 26
# Hellg,1world -> score: 25
# Hellg,1world -> score: 25
# Hellg,1world -> score: 25
# Hellg,1world -> score: 25
# Hellg,1world -> score: 25
# Hellg,1world -> score: 25
# Hellg,1world -> score: 25
# Hellg,0world -> score: 24
# Hellg,0world -> score: 24
# Hellg,0world -> score: 24
# Hellg,0world -> score: 24
# Hellg,0world -> score: 24
# Hellg,0world -> score: 24
# Hellg,0world -> score: 24
# Hellh,0world -> score: 23
# Hellh,0world -> score: 23
# Hellh,0world -> score: 23
# Helli,0world -> score: 22
# Helli,0world -> score: 22
# Helli,0world -> score: 22
# Helli,0world -> score: 22
# Helli,0world -> score: 22
# Helli,0world -> score: 22
# Helli,0world -> score: 22
# Helli,0world -> score: 22
# Helli,0world -> score: 22
# Hellj,0world -> score: 21
# Hellj,/world -> score: 20
# Hellj,/world -> score: 20
# Hellj,/world -> score: 20
# Hellj,/world -> score: 20
# Hellj,/world -> score: 20
# Hellj,/world -> score: 20
# Hellj,/world -> score: 20
# Hellj,/world -> score: 20
# Hellj,/world -> score: 20
# Hellj,/world -> score: 20
# Hellj,/world -> score: 20
# Hellk,/world -> score: 19
# Hellk,/world -> score: 19
# Hellk,/world -> score: 19
# Hellk,/world -> score: 19
# Hellk,.world -> score: 18
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,-world -> score: 17
# Hellk,,world -> score: 16
# Hellk,,world -> score: 16
# Hellk,,world -> score: 16
# Hellk,,world -> score: 16
# Hellk,,world -> score: 16
# Hellk,,world -> score: 16
# Helll,,world -> score: 15
# Helll,,world -> score: 15
# Helll,,world -> score: 15
# Helll,,world -> score: 15
# Helll,,world -> score: 15
# Helll,,world -> score: 15
# Helll,,world -> score: 15
# Helll,,world -> score: 15
# Helll,,world -> score: 15
# Helll,,world -> score: 15
# Helll,,world -> score: 15
# Helll,,world -> score: 15
# Hellm,,world -> score: 14
# Hellm,+world -> score: 13
# Hellm,+world -> score: 13
# Hellm,+world -> score: 13
# Helln,+world -> score: 12
# Helln,+world -> score: 12
# Helln,+world -> score: 12
# Helln,+world -> score: 12
# Helln,+world -> score: 12
# Helln,+world -> score: 12
# Helln,+world -> score: 12
# Helln,+world -> score: 12
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,+world -> score: 11
# Hello,*world -> score: 10
# Hello,)world -> score: 9
# Hello,)world -> score: 9
# Hello,)world -> score: 9
# Hello,)world -> score: 9
# Hello,)world -> score: 9
# Hello,)world -> score: 9
# Hello,)world -> score: 9
# Hello,(world -> score: 8
# Hello,(world -> score: 8
# Hello,(world -> score: 8
# Hello,(world -> score: 8
# Hello,(world -> score: 8
# Hello,'world -> score: 7
# Hello,'world -> score: 7
# Hello,'world -> score: 7
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,&world -> score: 6
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,%world -> score: 5
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,$world -> score: 4
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,#world -> score: 3
# Hello,"world -> score: 2
# Hello,"world -> score: 2
# Hello,"world -> score: 2
# Hello,"world -> score: 2
# Hello,"world -> score: 2
# Hello,"world -> score: 2
# Hello,"world -> score: 2
# Hello,"world -> score: 2
# Hello,"world -> score: 2
# Hello,"world -> score: 2
# Hello,!world -> score: 1
# Hello,!world -> score: 1
# Hello,!world -> score: 1
# Hello,!world -> score: 1
# Hello,!world -> score: 1
# Hello,!world -> score: 1
# Hello,!world -> score: 1
# Hello,!world -> score: 1
# Hello,!world -> score: 1
# Hello,!world -> score: 1
# Hello, world -> score: 0

# %%
print()
print("*************Simulated annealing***************")
print("steps:{}, best solution:'{}', best score:{}".format(iterations,best_sol,best_score))
# Out:
# *************Simulated annealing***************
# steps:14789, best solution:'Hello, world', best score:0

# %% [markdown]
# ## 4. Genetic algorithm
#
# This optimization technique is inspired by the theory of evolution. The algorithm starts with a population of random individuals, and selects the ones with the best fitness score (elite). It continues to the next generation with this group. In order to enrich the genetic pool in the current generation, the algorithm adds random mutations and crossover to the elite group. After predefined number of generations, the algorithm returns the top-fit individual.

# %% [markdown]
# ### 4.1. Mutation and crossover

# %%
# Mutation Operation
def string_mutation(individual):
    i = random.randint(0, len(individual) - 1)

    # mutation changes character at random position to any valid character   
    rchar = chr(random.randint(32, 122))

    individual = individual[0:i] + rchar + individual[(i + 1):]
    return individual


# Mate operation (crossover)
def string_crossover (s1, s2):
    # find the point of crossover
    i = random.randint (0, len(s1)-1)
    return s1[:i]+s2[i:]

# %% [markdown]
# ### 4.2. Algorithm
#
# Initial population - a list of random strings

# %%
def genetic_optimize(population, fitness_function,
                     mutation_function, mate_function,
                     mutation_probability, elite_ratio,
                     maxiterations):

    # How many winners to consider from each generation?
    original_population_size = len(population)
    top_elite = int(elite_ratio * original_population_size)

    # Main loop
    iterations = 0
    for i in range(maxiterations):
        iterations += 1
        individual_scores = [(fitness_function(v), v) for v in population]
        individual_scores.sort()
        ranked_individuals = [v for (s, v) in individual_scores]

        # Start with the pure winners
        population = ranked_individuals[0:top_elite]

        # Add mutated and bred forms of the winners
        while len(population) < original_population_size:
            if random.random() < mutation_probability:
                # Mutation
                c = random.randint(0, top_elite)
                population.append(mutation_function(ranked_individuals[c]))
            else:
                # Crossover
                c1 = random.randint(0, top_elite)
                c2 = random.randint(0, top_elite)
                population.append(mate_function(ranked_individuals[c1], ranked_individuals[c2]))

        # Print current best score
        if print_steps:
            print(individual_scores[0][1]," -> score:", individual_scores[0][0])

        if individual_scores[0][0] == 0:
            return (individual_scores[0][0],individual_scores[0][1], iterations)

    # returns the best solution
    return (individual_scores[0][0], individual_scores[0][1], iterations)



string_population = get_rand_population(2048, len(s), alphabet)
best_score, best_sol, iterations  = genetic_optimize(string_population, string_fitness,
                                string_mutation, string_crossover,
                                mutation_probability=0.25, elite_ratio=0.1,
                                maxiterations=100)
print()
print("*****************GENETIC ALGORITHM ***************")
print("generations:{}, best solution:'{}', best score:{}".format(iterations,best_sol,best_score))
# Out:
# hpnJN4(rx^ig  -> score: 168
# <fc_i#"yq^lX  -> score: 88
# G_pni#"yq^lX  -> score: 66
# L]ynd"#xrvka  -> score: 63
# Hgmqi*%jqmnb  -> score: 45
# Hgmqn*#xrvkg  -> score: 26
# Hgmqn*"yqtka  -> score: 23
# Hgmll( wltlh  -> score: 19
# Hglnn*#xotlc  -> score: 14
# Hglnn*#xotlc  -> score: 14
# Hglnn* wotlc  -> score: 10
# Hemln*!wotlc  -> score: 8
# Hemln* wotlc  -> score: 7
# Helln* wotkd  -> score: 6
# Helln- wotlc  -> score: 5
# Helln- wotld  -> score: 4
# Hello- wotld  -> score: 3
# Helln- wosld  -> score: 3
# Hello- world  -> score: 1
# Hello, wosld  -> score: 1
# Hello, wosld  -> score: 1
# Hello, world  -> score: 0
#
# *****************GENETIC ALGORITHM ***************
# generations:22, best solution:'Hello, world', best score:0

# %% [markdown]
# ### This is the end of the ''Hello, world'' demo.
# Copyright &copy; 2022 Marina Barsky
